# %% [markdown]
# # Non-dimensionalization of The CBC Condition
#
# Comete-Bellot and Corrsin performed a [turbulent experiment](https://acoustique.ec-lyon.fr/publi/comte-bellot_jfm71.pdf) at 1971. The recorded data have been to validate numerical methods in many papers.
#
# The 5.08cm grid setup is used in this file. The collected kinetic energy at different wavelength are listed as (also see table 3 of their paper)
#
# | $k, cm^{-1}$ | $\frac{tU_0}{M}=42$ | $\frac{tU_0}{M}=98$ | $\frac{tU_0}{M}=171$ |
# |--------------|---------------------|---------------------|----------------------|
# | 0.15         | -                   | -                   | 49.7                 |
# | 0.20         | 129                 | 106                 | 92                   |
# | 0.25         | 230                 | 196                 | 120                  |
# | 0.30         | 322                 | 195                 | 125                  |
# | 0.40         | 435                 | 202                 | 98                   |
# | 0.50         | 457                 | 168                 | 81.5                 |
# | 0.70         | 380                 | 127                 | 60.2                 |
# | 1.00         | 270                 | 79.2                | 39.4                 |
# | 1.50         | 168                 | 47.8                | 24.1                 |
# | 2.00         | 120                 | 34.6                | 16.5                 |
# | 2.50         | 89                  | 28.6                | 12.5                 |
# | 3.00         | 70.3                | 23.1                | 9.12                 |
# | 4.00         | 47                  | 14.3                | 5.62                 |
# | 6.00         | 24.7                | 5.95                | 1.69                 |
# | 8.00         | 12.6                | 2.23                | 0.52                 |
# | 10.00        | 7.42                | 0.9                 | 0.161                |
# | 12.50        | 3.96                | 0.363               | 0.052                |
# | 15.00        | 2.33                | 0.162               | 0.0141               |
# | 17.50        | 1.34                | 0.066               | -                    |
# | 20.00        | 0.8                 | 0.033               | -                    |
#
# where $U_0=10m/s$ and $M=5.08cm$. Hence, we could compute the end time as 0.21336, 0.49784 and 0.86868, respectively. The Taylor microscale Reynolds numbers $Re_{\lambda} = u^`\lambda/\nu$ are 71.6, 65.1, 60.7, respectively. The grid Reynolds number of the experiment is $Re=34000$, then we have the dynamic viscosity about 0.000015.
#
# In the simulation, the velocity field should be initialized based on the energy spectra at $\frac{tU_0}{M}=42$, and then is evolved to $\frac{tU_0}{M}=98$ and $\frac{tU_0}{M}=171$. If we set the start time at $\frac{tU_0}{M}=42$ as 0.0, the end time for next two state should be 0.28448 and 0.65532, respectively.
#
# To simulate this isotropic flow in a $(2\pi)^3$ domain, the length, velocity and time should be scaled by the reference length $L_{ref}=10.8M/2\pi$, the reference velocity $U_{ref}=\sqrt{3/2}*22.2cm/s$ and the reference time $t_{ref}=L_{ref}/U_{ref}$.
#
# Now we import numpy and define the reference values (pay attention to the unit):

# %%
import numpy as np

u_ref = np.sqrt(3/2) * 22.2
l_ref = 10.8 * 5.08 / 2 / np.pi
t_ref = l_ref / u_ref
ek_ref = l_ref**3 / t_ref**2

# %% [markdown]
# The wavenumber, kinetic energy should be non-dimensionalized with the reference values. Then we could plot them in log scale

# %%
import matplotlib.pyplot as plt

k      = np.array([0.15, 0.20, 0.25, 0.30, 0.40, 0.50, 0.70, 1.00, 1.50, 2.00, 2.50, 3.00, 4.00, 6.00, 8.00, 10.00, 12.50, 15.00, 17.50, 20.00]) * l_ref
# for tU0/M = 42, k starts from 0.2
E_k42  = np.array([      129,  230,  322,  435,  457,  380,  270,  168,  120,  89,   70.3, 47,   24.7, 12.6, 7.42,  3.96,  2.33,  1.34,  0.8]) / ek_ref
# for tU0/M = 98, k starts from 0.2
E_k98  = np.array([      106,  196,  195,  202,  168,  127,  79.2, 47.8, 34.6, 28.6, 23.1, 14.3, 5.95, 2.23, 0.9,   0.363, 0.162, 0.066, 0.033]) / ek_ref
# for tU0/M = 171, k starts from 0.15
E_k171 = np.array([49.7, 92,   120,  125,  98,   81.5, 60.2, 39.4, 24.1, 16.5, 12.5, 9.12, 5.62, 1.69, 0.52, 0.161, 0.052, 0.0141]) / ek_ref
plt.figure(dpi=100)
plt.scatter(k[1:14], E_k42[:13], marker="s", label=r"$Re_\lambda=71.6$")
plt.scatter(k[1:14], E_k98[:13], marker="o", label=r"$Re_\lambda=65.3$")
plt.scatter(k[:13], E_k171[:13], marker="^", label=r"$Re_\lambda=60.7$")
plt.yscale("log")
plt.xscale("log")
plt.legend()
plt.ylim(0.0005, 0.1)
plt.xlim(1, 33)
plt.grid(which="both", linestyle=":")
plt.tight_layout()

# %% [markdown]
# The end time should also be rescaled as

# %%
end_t1 = 0.21336
end_t2 = 0.49784
end_t3 = 0.86868

evol_end_time1 = (end_t2 - end_t1) / t_ref
evol_end_time2 = (end_t3 - end_t1) / t_ref
evol_end_time1, evol_end_time2
# Out:
# (0.885814416031794, 2.0405367797875256)

# %% [markdown]
# Since the energy are not evenly distributed and the corresponding wavenumber is not an integer, we need to reconstruct the energy at integer wavenumber to build the reference energy spectra. The polynomial interpolation are normally used. Here we use the Gaussian process (GP) to find the missed energy.
#
# Note that we build the regression model at log scale, and the input should be normalized for GP.

# %%
import gpytorch
import torch

x = np.log(k[1:])
y = np.log(E_k42)
normalized_x = x / (x.max() - x.min())
train_x = torch.tensor(normalized_x.reshape(-1, 1))
train_y = torch.tensor(y)


class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# initialize likelihood and model
likelihood = gpytorch.likelihoods.GaussianLikelihood()
model = ExactGPModel(train_x, train_y, likelihood)

# %%
training_iter = 100
model.train()
likelihood.train()

optimizer = torch.optim.Adam(model.parameters(), lr=0.1)
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

for i in range(training_iter):
    # Zero gradients from previous iteration
    optimizer.zero_grad()
    output = model(train_x)
    loss = -mll(output, train_y)
    loss.backward()
    print('Iter %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
        i + 1, training_iter, loss.item(),
        model.covar_module.base_kernel.lengthscale.item(),
        model.likelihood.noise.item()
    ))
    optimizer.step()
# Out:
# Iter 1/100 - Loss: 3.273   lengthscale: 0.693   noise: 0.693
# Iter 2/100 - Loss: 3.086   lengthscale: 0.644   noise: 0.744
# Iter 3/100 - Loss: 2.922   lengthscale: 0.599   noise: 0.797
# Iter 4/100 - Loss: 2.777   lengthscale: 0.556   noise: 0.850
# Iter 5/100 - Loss: 2.650   lengthscale: 0.516   noise: 0.902
# Iter 6/100 - Loss: 2.538   lengthscale: 0.479   noise: 0.949
# Iter 7/100 - Loss: 2.440   lengthscale: 0.445   noise: 0.991
# Iter 8/100 - Loss: 2.353   lengthscale: 0.416   noise: 1.026
# Iter 9/100 - Loss: 2.277   lengthscale: 0.392   noise: 1.051
# Iter 10/100 - Loss: 2.207   lengthscale: 0.375   noise: 1.066
# Iter 11/100 - Loss: 2.142   lengthscale: 0.366   noise: 1.073
# Iter 12/100 - Loss: 2.081   lengthscale: 0.363   noise: 1.070
# Iter 13/100 - Loss: 2.024   lengthscale: 0.364   noise: 1.060
# Iter 14/100 - Loss: 1.969   lengthscale: 0.369   noise: 1.043
# Iter 15/100 - Loss: 1.918   lengthscale: 0.374   noise: 1.020
# Iter 16/100 - Loss: 1.870   lengthscale: 0.380   noise: 0.991
# Iter 17/100 - Loss: 1.824   lengthscale: 0.384   noise: 0.958
# Iter 18/100 - Loss: 1.780   lengthscale: 0.386   noise: 0.922
# Iter 19/100 - Loss: 1.736   lengthscale: 0.385   noise: 0.883
# Iter 20/100 - Loss: 1.694   lengthscale: 0.381   noise: 0.842
# Iter 21/100 - Loss: 1.652   lengthscale: 0.375   noise: 0.799
# Iter 22/100 - Loss: 1.612   lengthscale: 0.369   noise: 0.755
# Iter 23/100 - Loss: 1.572   lengthscale: 0.362   noise: 0.711
# Iter 24/100 - Loss: 1.533   lengthscale: 0.357   noise: 0.667
# Iter 25/100 - Loss: 1.495   lengthscale: 0.353   noise: 0.624
# Iter 26/100 - Loss: 1.457   lengthscale: 0.351   noise: 0.581
# Iter 27/100 - Loss: 1.419   lengthscale: 0.351   noise: 0.540
# Iter 28/100 - Loss: 1.382   lengthscale: 0.352   noise: 0.500
# Iter 29/100 - Loss: 1.345   lengthscale: 0.355   noise: 0.461
# Iter 30/100 - Loss: 1.309   lengthscale: 0.359   noise: 0.424
# Iter 31/100 - Loss: 1.273   lengthscale: 0.364   noise: 0.390
# Iter 32/100 - Loss: 1.237   lengthscale: 0.368   noise: 0.357
# Iter 33/100 - Loss: 1.203   lengthscale: 0.372   noise: 0.326
# Iter 34/100 - Loss: 1.169   lengthscale: 0.375   noise: 0.297
# Iter 35/100 - Loss: 1.136   lengthscale: 0.376   noise: 0.271
# Iter 36/100 - Loss: 1.103   lengthscale: 0.376   noise: 0.246
# Iter 37/100 - Loss: 1.071   lengthscale: 0.373   noise: 0.224
# Iter 38/100 - Loss: 1.038   lengthscale: 0.366   noise: 0.203
# Iter 39/100 - Loss: 1.004   lengthscale: 0.356   noise: 0.184
# Iter 40/100 - Loss: 0.965   lengthscale: 0.340   noise: 0.166
# Iter 41/100 - Loss: 0.917   lengthscale: 0.318   noise: 0.150
# Iter 42/100 - Loss: 0.861   lengthscale: 0.294   noise: 0.136
# Iter 43/100 - Loss: 0.807   lengthscale: 0.268   noise: 0.122
# Iter 44/100 - Loss: 0.766   lengthscale: 0.244   noise: 0.110
# Iter 45/100 - Loss: 0.735   lengthscale: 0.227   noise: 0.098
# Iter 46/100 - Loss: 0.704   lengthscale: 0.217   noise: 0.088
# Iter 47/100 - Loss: 0.668   lengthscale: 0.214   noise: 0.078
# Iter 48/100 - Loss: 0.626   lengthscale: 0.216   noise: 0.070
# Iter 49/100 - Loss: 0.581   lengthscale: 0.223   noise: 0.062
# Iter 50/100 - Loss: 0.533   lengthscale: 0.234   noise: 0.055
# Iter 51/100 - Loss: 0.486   lengthscale: 0.248   noise: 0.049
# Iter 52/100 - Loss: 0.442   lengthscale: 0.263   noise: 0.043
# Iter 53/100 - Loss: 0.404   lengthscale: 0.279   noise: 0.038
# Iter 54/100 - Loss: 0.371   lengthscale: 0.291   noise: 0.034
# Iter 55/100 - Loss: 0.337   lengthscale: 0.297   noise: 0.030
# Iter 56/100 - Loss: 0.296   lengthscale: 0.296   noise: 0.027
# Iter 57/100 - Loss: 0.254   lengthscale: 0.289   noise: 0.024
# Iter 58/100 - Loss: 0.214   lengthscale: 0.280   noise: 0.021
# Iter 59/100 - Loss: 0.178   lengthscale: 0.272   noise: 0.019
# Iter 60/100 - Loss: 0.144   lengthscale: 0.265   noise: 0.017
# Iter 61/100 - Loss: 0.110   lengthscale: 0.260   noise: 0.015
# Iter 62/100 - Loss: 0.076   lengthscale: 0.257   noise: 0.013
# Iter 63/100 - Loss: 0.042   lengthscale: 0.256   noise: 0.012
# Iter 64/100 - Loss: 0.008   lengthscale: 0.256   noise: 0.010
# Iter 65/100 - Loss: -0.025   lengthscale: 0.258   noise: 0.009
# Iter 66/100 - Loss: -0.058   lengthscale: 0.260   noise: 0.008
# Iter 67/100 - Loss: -0.090   lengthscale: 0.263   noise: 0.007
# Iter 68/100 - Loss: -0.122   lengthscale: 0.265   noise: 0.007
# Iter 69/100 - Loss: -0.152   lengthscale: 0.267   noise: 0.006
# Iter 70/100 - Loss: -0.182   lengthscale: 0.267   noise: 0.005
# Iter 71/100 - Loss: -0.212   lengthscale: 0.267   noise: 0.005
# Iter 72/100 - Loss: -0.241   lengthscale: 0.265   noise: 0.004
# Iter 73/100 - Loss: -0.270   lengthscale: 0.262   noise: 0.004
# Iter 74/100 - Loss: -0.297   lengthscale: 0.260   noise: 0.003
# Iter 75/100 - Loss: -0.322   lengthscale: 0.259   noise: 0.003
# Iter 76/100 - Loss: -0.347   lengthscale: 0.259   noise: 0.003
# Iter 77/100 - Loss: -0.372   lengthscale: 0.261   noise: 0.002
# Iter 78/100 - Loss: -0.396   lengthscale: 0.265   noise: 0.002
# Iter 79/100 - Loss: -0.418   lengthscale: 0.268   noise: 0.002
# Iter 80/100 - Loss: -0.438   lengthscale: 0.271   noise: 0.002
# Iter 81/100 - Loss: -0.458   lengthscale: 0.273   noise: 0.002
# Iter 82/100 - Loss: -0.477   lengthscale: 0.272   noise: 0.002
# Iter 83/100 - Loss: -0.494   lengthscale: 0.271   noise: 0.001
# Iter 84/100 - Loss: -0.510   lengthscale: 0.270   noise: 0.001
# Iter 85/100 - Loss: -0.525   lengthscale: 0.270   noise: 0.001
# Iter 86/100 - Loss: -0.538   lengthscale: 0.272   noise: 0.001
# Iter 87/100 - Loss: -0.551   lengthscale: 0.275   noise: 0.001
# Iter 88/100 - Loss: -0.562   lengthscale: 0.278   noise: 0.001
# Iter 89/100 - Loss: -0.572   lengthscale: 0.280   noise: 0.001
# Iter 90/100 - Loss: -0.581   lengthscale: 0.280   noise: 0.001
# Iter 91/100 - Loss: -0.590   lengthscale: 0.279   noise: 0.001
# Iter 92/100 - Loss: -0.597   lengthscale: 0.279   noise: 0.001
# Iter 93/100 - Loss: -0.603   lengthscale: 0.279   noise: 0.001
# Iter 94/100 - Loss: -0.609   lengthscale: 0.280   noise: 0.001
# Iter 95/100 - Loss: -0.614   lengthscale: 0.282   noise: 0.001
# Iter 96/100 - Loss: -0.619   lengthscale: 0.284   noise: 0.001
# Iter 97/100 - Loss: -0.623   lengthscale: 0.286   noise: 0.001
# Iter 98/100 - Loss: -0.626   lengthscale: 0.286   noise: 0.001
# Iter 99/100 - Loss: -0.630   lengthscale: 0.285   noise: 0.001
# Iter 100/100 - Loss: -0.633   lengthscale: 0.285   noise: 0.001

# %% [markdown]
# We predict the output for wavenumber from 1 to 55 which corresponds to the maximum wavenumber in our setting.

# %%
model.eval()
likelihood.eval()

with torch.no_grad(), gpytorch.settings.fast_pred_var():
    test_x = torch.linspace(0, 1.3, 51).double()
    observed_pred = likelihood(model(test_x))
    
k_integer = torch.arange(1, 56).reshape(-1, 1).double()
log_k = torch.log(k_integer) / (x.max() - x.min())
# torch.cat([0], log_k)
with torch.no_grad(), gpytorch.settings.fast_pred_var():
    observed_pred_k = likelihood(model(log_k))

# %% [markdown]
# Back to linear space, we plot our results in log scale.

# %%
with torch.no_grad():
    # Initialize plot
    f, ax = plt.subplots(1, 1, dpi=100)
    
    raw_train_x = np.exp(train_x.numpy() * (x.max() - x.min()))
    raw_test_x  = np.exp(test_x.numpy() * (x.max() - x.min()))
    raw_integer_k = np.exp(log_k.numpy() * (x.max() - x.min()))
    
    lower, upper = observed_pred.confidence_region()
    # plot the fitted Gaussian and training data
    ax.scatter(raw_train_x, np.exp(train_y.numpy()), marker=".", color="black", label="Training data")
    ax.plot(raw_test_x, np.exp(observed_pred.mean.numpy()), 'b', label="Fitted GP")
    ax.fill_between(raw_test_x, np.exp(lower.numpy()), np.exp(upper.numpy()), alpha=0.3)
    
    # plot predicted value with integer k
    ax.scatter(raw_integer_k, np.exp(observed_pred_k.mean.numpy()), marker="^", s=10, color="red", label="Integer k")
    
    ax.set_yscale("log")
    ax.set_xscale("log")
    ax.legend()
    ax.grid(which="both", linestyle=":", alpha=0.3)
    ax.set_title(r"$Re_\lambda=71.6$")
    plt.tight_layout()

# %% [markdown]
# Now we have the energy at wavenumber from 1 to 55. Note that wavenumber 0 has zero energy

# %%
np.exp(observed_pred_k.mean.numpy())
# Out:
# array([0.00327365, 0.02886479, 0.05957186, 0.07045104, 0.0677236 ,
#        0.0604232 , 0.05272768, 0.04595604, 0.04032604, 0.03571568,
#        0.03193417, 0.02880539, 0.02618687, 0.02396867, 0.02206723,
#        0.02041924, 0.01897645, 0.0177018 , 0.01656655, 0.01554815,
#        0.01462875, 0.013794  , 0.01303231, 0.01233418, 0.01169175,
#        0.01109847, 0.01054883, 0.01003816, 0.00956245, 0.00911827,
#        0.00870262, 0.00831291, 0.00794686, 0.00760245, 0.00727791,
#        0.00697166, 0.00668227, 0.00640849, 0.00614917, 0.00590328,
#        0.00566988, 0.00544815, 0.00523729, 0.00503661, 0.00484547,
#        0.00466328, 0.00448949, 0.0043236 , 0.00416515, 0.00401373,
#        0.00386893, 0.00373039, 0.00359777, 0.00347075, 0.00334904])

# %% [markdown]
# We use the same method to predict the energy spectra at $Re_{\lambda}=65.1$ and $Re_{\lambda}=60.7$

# %%
x = np.log(k[1:])
y = np.log(E_k98)
normalized_x = x / (x.max() - x.min())
train_x = torch.tensor(normalized_x.reshape(-1, 1))
train_y = torch.tensor(y)
model = ExactGPModel(train_x, train_y, likelihood)

training_iter = 100
model.train()
likelihood.train()

optimizer = torch.optim.Adam(model.parameters(), lr=0.1)
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

for i in range(training_iter):
    # Zero gradients from previous iteration
    optimizer.zero_grad()
    output = model(train_x)
    loss = -mll(output, train_y)
    loss.backward()
    print('Iter %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
        i + 1, training_iter, loss.item(),
        model.covar_module.base_kernel.lengthscale.item(),
        model.likelihood.noise.item()
    ))
    optimizer.step()

model.eval()
likelihood.eval()

with torch.no_grad(), gpytorch.settings.fast_pred_var():
    test_x = torch.linspace(0, 1.3, 51).double()
    observed_pred = likelihood(model(test_x))
    
k_integer = torch.arange(1, 56).reshape(-1, 1).double()
log_k = torch.log(k_integer) / (x.max() - x.min())
# torch.cat([0], log_k)
with torch.no_grad(), gpytorch.settings.fast_pred_var():
    observed_pred_k = likelihood(model(log_k))
# Out:
# Iter 1/100 - Loss: 65.508   lengthscale: 0.693   noise: 0.001
# Iter 2/100 - Loss: 53.500   lengthscale: 0.644   noise: 0.001
# Iter 3/100 - Loss: 42.088   lengthscale: 0.598   noise: 0.001
# Iter 4/100 - Loss: 31.915   lengthscale: 0.554   noise: 0.001
# Iter 5/100 - Loss: 23.520   lengthscale: 0.513   noise: 0.001
# Iter 6/100 - Loss: 17.096   lengthscale: 0.474   noise: 0.001
# Iter 7/100 - Loss: 12.532   lengthscale: 0.439   noise: 0.001
# Iter 8/100 - Loss: 9.533   lengthscale: 0.408   noise: 0.001
# Iter 9/100 - Loss: 7.694   lengthscale: 0.380   noise: 0.001
# Iter 10/100 - Loss: 6.581   lengthscale: 0.355   noise: 0.001
# Iter 11/100 - Loss: 5.852   lengthscale: 0.334   noise: 0.001
# Iter 12/100 - Loss: 5.304   lengthscale: 0.316   noise: 0.001
# Iter 13/100 - Loss: 4.851   lengthscale: 0.300   noise: 0.001
# Iter 14/100 - Loss: 4.469   lengthscale: 0.286   noise: 0.001
# Iter 15/100 - Loss: 4.151   lengthscale: 0.273   noise: 0.001
# Iter 16/100 - Loss: 3.888   lengthscale: 0.263   noise: 0.001
# Iter 17/100 - Loss: 3.669   lengthscale: 0.253   noise: 0.001
# Iter 18/100 - Loss: 3.480   lengthscale: 0.245   noise: 0.001
# Iter 19/100 - Loss: 3.312   lengthscale: 0.237   noise: 0.001
# Iter 20/100 - Loss: 3.156   lengthscale: 0.230   noise: 0.001
# Iter 21/100 - Loss: 3.010   lengthscale: 0.224   noise: 0.001
# Iter 22/100 - Loss: 2.872   lengthscale: 0.219   noise: 0.001
# Iter 23/100 - Loss: 2.741   lengthscale: 0.214   noise: 0.002
# Iter 24/100 - Loss: 2.620   lengthscale: 0.210   noise: 0.002
# Iter 25/100 - Loss: 2.507   lengthscale: 0.206   noise: 0.002
# Iter 26/100 - Loss: 2.403   lengthscale: 0.202   noise: 0.002
# Iter 27/100 - Loss: 2.308   lengthscale: 0.199   noise: 0.002
# Iter 28/100 - Loss: 2.220   lengthscale: 0.196   noise: 0.002
# Iter 29/100 - Loss: 2.141   lengthscale: 0.193   noise: 0.002
# Iter 30/100 - Loss: 2.068   lengthscale: 0.190   noise: 0.002
# Iter 31/100 - Loss: 2.001   lengthscale: 0.188   noise: 0.002
# Iter 32/100 - Loss: 1.940   lengthscale: 0.186   noise: 0.002
# Iter 33/100 - Loss: 1.883   lengthscale: 0.184   noise: 0.002
# Iter 34/100 - Loss: 1.830   lengthscale: 0.182   noise: 0.002
# Iter 35/100 - Loss: 1.780   lengthscale: 0.181   noise: 0.002
# Iter 36/100 - Loss: 1.733   lengthscale: 0.179   noise: 0.002
# Iter 37/100 - Loss: 1.690   lengthscale: 0.178   noise: 0.002
# Iter 38/100 - Loss: 1.648   lengthscale: 0.177   noise: 0.002
# Iter 39/100 - Loss: 1.609   lengthscale: 0.175   noise: 0.002
# Iter 40/100 - Loss: 1.571   lengthscale: 0.174   noise: 0.002
# Iter 41/100 - Loss: 1.535   lengthscale: 0.174   noise: 0.002
# Iter 42/100 - Loss: 1.501   lengthscale: 0.173   noise: 0.002
# Iter 43/100 - Loss: 1.468   lengthscale: 0.172   noise: 0.002
# Iter 44/100 - Loss: 1.437   lengthscale: 0.171   noise: 0.002
# Iter 45/100 - Loss: 1.407   lengthscale: 0.171   noise: 0.002
# Iter 46/100 - Loss: 1.378   lengthscale: 0.170   noise: 0.002
# Iter 47/100 - Loss: 1.350   lengthscale: 0.170   noise: 0.002
# Iter 48/100 - Loss: 1.323   lengthscale: 0.169   noise: 0.002
# Iter 49/100 - Loss: 1.297   lengthscale: 0.169   noise: 0.002
# Iter 50/100 - Loss: 1.272   lengthscale: 0.168   noise: 0.002
# Iter 51/100 - Loss: 1.248   lengthscale: 0.168   noise: 0.002
# Iter 52/100 - Loss: 1.225   lengthscale: 0.168   noise: 0.002
# Iter 53/100 - Loss: 1.202   lengthscale: 0.168   noise: 0.002
# Iter 54/100 - Loss: 1.180   lengthscale: 0.167   noise: 0.002
# Iter 55/100 - Loss: 1.159   lengthscale: 0.167   noise: 0.002
# Iter 56/100 - Loss: 1.139   lengthscale: 0.167   noise: 0.002
# Iter 57/100 - Loss: 1.119   lengthscale: 0.167   noise: 0.002
# Iter 58/100 - Loss: 1.100   lengthscale: 0.167   noise: 0.002
# Iter 59/100 - Loss: 1.082   lengthscale: 0.166   noise: 0.002
# Iter 60/100 - Loss: 1.064   lengthscale: 0.166   noise: 0.002
# Iter 61/100 - Loss: 1.046   lengthscale: 0.166   noise: 0.002
# Iter 62/100 - Loss: 1.030   lengthscale: 0.166   noise: 0.002
# Iter 63/100 - Loss: 1.013   lengthscale: 0.166   noise: 0.002
# Iter 64/100 - Loss: 0.997   lengthscale: 0.166   noise: 0.002
# Iter 65/100 - Loss: 0.982   lengthscale: 0.166   noise: 0.002
# Iter 66/100 - Loss: 0.967   lengthscale: 0.166   noise: 0.002
# Iter 67/100 - Loss: 0.953   lengthscale: 0.166   noise: 0.002
# Iter 68/100 - Loss: 0.939   lengthscale: 0.166   noise: 0.002
# Iter 69/100 - Loss: 0.925   lengthscale: 0.166   noise: 0.002
# Iter 70/100 - Loss: 0.912   lengthscale: 0.166   noise: 0.002
# Iter 71/100 - Loss: 0.899   lengthscale: 0.166   noise: 0.002
# Iter 72/100 - Loss: 0.886   lengthscale: 0.166   noise: 0.002
# Iter 73/100 - Loss: 0.874   lengthscale: 0.166   noise: 0.002
# Iter 74/100 - Loss: 0.862   lengthscale: 0.166   noise: 0.002
# Iter 75/100 - Loss: 0.850   lengthscale: 0.166   noise: 0.002
# Iter 76/100 - Loss: 0.839   lengthscale: 0.166   noise: 0.002
# Iter 77/100 - Loss: 0.828   lengthscale: 0.166   noise: 0.002
# Iter 78/100 - Loss: 0.818   lengthscale: 0.166   noise: 0.002
# Iter 79/100 - Loss: 0.807   lengthscale: 0.166   noise: 0.002
# Iter 80/100 - Loss: 0.797   lengthscale: 0.166   noise: 0.002
# Iter 81/100 - Loss: 0.787   lengthscale: 0.166   noise: 0.002
# Iter 82/100 - Loss: 0.778   lengthscale: 0.166   noise: 0.002
# Iter 83/100 - Loss: 0.769   lengthscale: 0.166   noise: 0.003
# Iter 84/100 - Loss: 0.760   lengthscale: 0.166   noise: 0.003
# Iter 85/100 - Loss: 0.751   lengthscale: 0.166   noise: 0.003
# Iter 86/100 - Loss: 0.742   lengthscale: 0.167   noise: 0.003
# Iter 87/100 - Loss: 0.734   lengthscale: 0.167   noise: 0.003
# Iter 88/100 - Loss: 0.726   lengthscale: 0.167   noise: 0.003
# Iter 89/100 - Loss: 0.718   lengthscale: 0.167   noise: 0.003
# Iter 90/100 - Loss: 0.710   lengthscale: 0.167   noise: 0.003
# Iter 91/100 - Loss: 0.702   lengthscale: 0.167   noise: 0.003
# Iter 92/100 - Loss: 0.695   lengthscale: 0.167   noise: 0.003
# Iter 93/100 - Loss: 0.688   lengthscale: 0.167   noise: 0.003
# Iter 94/100 - Loss: 0.681   lengthscale: 0.167   noise: 0.003
# Iter 95/100 - Loss: 0.674   lengthscale: 0.167   noise: 0.003
# Iter 96/100 - Loss: 0.667   lengthscale: 0.168   noise: 0.003
# Iter 97/100 - Loss: 0.661   lengthscale: 0.168   noise: 0.003
# Iter 98/100 - Loss: 0.655   lengthscale: 0.168   noise: 0.003
# Iter 99/100 - Loss: 0.648   lengthscale: 0.168   noise: 0.003
# Iter 100/100 - Loss: 0.642   lengthscale: 0.168   noise: 0.003

# %%
with torch.no_grad():
    # Initialize plot
    f, ax = plt.subplots(1, 1, dpi=100)
    
    raw_train_x = np.exp(train_x.numpy() * (x.max() - x.min()))
    raw_test_x  = np.exp(test_x.numpy() * (x.max() - x.min()))
    raw_integer_k = np.exp(log_k.numpy() * (x.max() - x.min()))
    
    lower, upper = observed_pred.confidence_region()
    # plot the fitted Gaussian and training data
    ax.scatter(raw_train_x, np.exp(train_y.numpy()), marker=".", color="black", label="Training data")
    ax.plot(raw_test_x, np.exp(observed_pred.mean.numpy()), 'b', label="Fitted GP")
    ax.fill_between(raw_test_x, np.exp(lower.numpy()), np.exp(upper.numpy()), alpha=0.3)
    
    # plot predicted value with integer k
    ax.scatter(raw_integer_k, np.exp(observed_pred_k.mean.numpy()), marker="^", s=10, color="red", label="Integer k")
    
    ax.set_yscale("log")
    ax.set_xscale("log")
    ax.legend()
    ax.grid(which="both", linestyle=":", alpha=0.3)
    ax.set_title(r"$Re_\lambda=65.1$")
    plt.tight_layout()

# %%
np.exp(observed_pred_k.mean.numpy())
# Out:
# array([0.00254815, 0.02360327, 0.03286731, 0.028333  , 0.02337858,
#        0.01950898, 0.01643993, 0.01397253, 0.01199944, 0.01043572,
#        0.00920229, 0.00822822, 0.00745394, 0.00683177, 0.00632467,
#        0.00590432, 0.00554929, 0.0052434 , 0.00497449, 0.00473342,
#        0.00451337, 0.0043093 , 0.00411749, 0.00393527, 0.00376074,
#        0.0035926 , 0.00343   , 0.00327243, 0.00311958, 0.00297133,
#        0.00282767, 0.00268865, 0.00255434, 0.00242483, 0.00230021,
#        0.00218054, 0.00206584, 0.00195615, 0.00185142, 0.00175162,
#        0.00165666, 0.00156645, 0.00148087, 0.00139978, 0.00132303,
#        0.00125045, 0.00118188, 0.00111714, 0.00105606, 0.00099846,
#        0.00094416, 0.00089299, 0.00084478, 0.00079936, 0.00075658])

# %%
x = np.log(k[:-2])
y = np.log(E_k171)
normalized_x = x / (x.max() - x.min())
train_x = torch.tensor(normalized_x.reshape(-1, 1))
train_y = torch.tensor(y)
model = ExactGPModel(train_x, train_y, likelihood)

training_iter = 100
model.train()
likelihood.train()

optimizer = torch.optim.Adam(model.parameters(), lr=0.1)
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

for i in range(training_iter):
    # Zero gradients from previous iteration
    optimizer.zero_grad()
    output = model(train_x)
    loss = -mll(output, train_y)
    loss.backward()
    print('Iter %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
        i + 1, training_iter, loss.item(),
        model.covar_module.base_kernel.lengthscale.item(),
        model.likelihood.noise.item()
    ))
    optimizer.step()

model.eval()
likelihood.eval()

with torch.no_grad(), gpytorch.settings.fast_pred_var():
    test_x = torch.linspace(0, 1.3, 51).double()
    observed_pred = likelihood(model(test_x))
    
k_integer = torch.arange(1, 56).reshape(-1, 1).double()
log_k = torch.log(k_integer) / (x.max() - x.min())
# torch.cat([0], log_k)
with torch.no_grad(), gpytorch.settings.fast_pred_var():
    observed_pred_k = likelihood(model(log_k))
# Out:
# Iter 1/100 - Loss: 35.495   lengthscale: 0.693   noise: 0.003
# Iter 2/100 - Loss: 30.763   lengthscale: 0.644   noise: 0.003
# Iter 3/100 - Loss: 26.583   lengthscale: 0.598   noise: 0.003
# Iter 4/100 - Loss: 22.722   lengthscale: 0.555   noise: 0.004
# Iter 5/100 - Loss: 19.039   lengthscale: 0.514   noise: 0.004
# Iter 6/100 - Loss: 15.546   lengthscale: 0.474   noise: 0.004
# Iter 7/100 - Loss: 12.395   lengthscale: 0.438   noise: 0.005
# Iter 8/100 - Loss: 9.774   lengthscale: 0.403   noise: 0.005
# Iter 9/100 - Loss: 7.790   lengthscale: 0.371   noise: 0.005
# Iter 10/100 - Loss: 6.413   lengthscale: 0.342   noise: 0.006
# Iter 11/100 - Loss: 5.506   lengthscale: 0.316   noise: 0.006
# Iter 12/100 - Loss: 4.896   lengthscale: 0.293   noise: 0.006
# Iter 13/100 - Loss: 4.438   lengthscale: 0.273   noise: 0.007
# Iter 14/100 - Loss: 4.053   lengthscale: 0.256   noise: 0.007
# Iter 15/100 - Loss: 3.721   lengthscale: 0.241   noise: 0.007
# Iter 16/100 - Loss: 3.443   lengthscale: 0.228   noise: 0.008
# Iter 17/100 - Loss: 3.221   lengthscale: 0.216   noise: 0.008
# Iter 18/100 - Loss: 3.048   lengthscale: 0.206   noise: 0.008
# Iter 19/100 - Loss: 2.909   lengthscale: 0.197   noise: 0.008
# Iter 20/100 - Loss: 2.795   lengthscale: 0.189   noise: 0.009
# Iter 21/100 - Loss: 2.695   lengthscale: 0.183   noise: 0.009
# Iter 22/100 - Loss: 2.605   lengthscale: 0.177   noise: 0.009
# Iter 23/100 - Loss: 2.524   lengthscale: 0.171   noise: 0.009
# Iter 24/100 - Loss: 2.449   lengthscale: 0.167   noise: 0.009
# Iter 25/100 - Loss: 2.380   lengthscale: 0.163   noise: 0.010
# Iter 26/100 - Loss: 2.317   lengthscale: 0.159   noise: 0.010
# Iter 27/100 - Loss: 2.258   lengthscale: 0.156   noise: 0.010
# Iter 28/100 - Loss: 2.202   lengthscale: 0.154   noise: 0.010
# Iter 29/100 - Loss: 2.150   lengthscale: 0.152   noise: 0.010
# Iter 30/100 - Loss: 2.100   lengthscale: 0.150   noise: 0.010
# Iter 31/100 - Loss: 2.052   lengthscale: 0.148   noise: 0.010
# Iter 32/100 - Loss: 2.006   lengthscale: 0.147   noise: 0.010
# Iter 33/100 - Loss: 1.961   lengthscale: 0.146   noise: 0.010
# Iter 34/100 - Loss: 1.918   lengthscale: 0.145   noise: 0.011
# Iter 35/100 - Loss: 1.877   lengthscale: 0.144   noise: 0.011
# Iter 36/100 - Loss: 1.836   lengthscale: 0.144   noise: 0.011
# Iter 37/100 - Loss: 1.797   lengthscale: 0.144   noise: 0.011
# Iter 38/100 - Loss: 1.759   lengthscale: 0.143   noise: 0.011
# Iter 39/100 - Loss: 1.721   lengthscale: 0.143   noise: 0.011
# Iter 40/100 - Loss: 1.685   lengthscale: 0.144   noise: 0.011
# Iter 41/100 - Loss: 1.650   lengthscale: 0.144   noise: 0.011
# Iter 42/100 - Loss: 1.616   lengthscale: 0.144   noise: 0.011
# Iter 43/100 - Loss: 1.583   lengthscale: 0.145   noise: 0.011
# Iter 44/100 - Loss: 1.550   lengthscale: 0.145   noise: 0.011
# Iter 45/100 - Loss: 1.519   lengthscale: 0.146   noise: 0.011
# Iter 46/100 - Loss: 1.489   lengthscale: 0.146   noise: 0.011
# Iter 47/100 - Loss: 1.459   lengthscale: 0.147   noise: 0.011
# Iter 48/100 - Loss: 1.431   lengthscale: 0.148   noise: 0.011
# Iter 49/100 - Loss: 1.403   lengthscale: 0.149   noise: 0.011
# Iter 50/100 - Loss: 1.377   lengthscale: 0.149   noise: 0.011
# Iter 51/100 - Loss: 1.351   lengthscale: 0.150   noise: 0.011
# Iter 52/100 - Loss: 1.326   lengthscale: 0.151   noise: 0.011
# Iter 53/100 - Loss: 1.301   lengthscale: 0.152   noise: 0.011
# Iter 54/100 - Loss: 1.278   lengthscale: 0.153   noise: 0.011
# Iter 55/100 - Loss: 1.255   lengthscale: 0.154   noise: 0.011
# Iter 56/100 - Loss: 1.233   lengthscale: 0.155   noise: 0.011
# Iter 57/100 - Loss: 1.212   lengthscale: 0.156   noise: 0.011
# Iter 58/100 - Loss: 1.192   lengthscale: 0.158   noise: 0.011
# Iter 59/100 - Loss: 1.172   lengthscale: 0.159   noise: 0.011
# Iter 60/100 - Loss: 1.153   lengthscale: 0.160   noise: 0.011
# Iter 61/100 - Loss: 1.135   lengthscale: 0.161   noise: 0.011
# Iter 62/100 - Loss: 1.117   lengthscale: 0.162   noise: 0.011
# Iter 63/100 - Loss: 1.100   lengthscale: 0.163   noise: 0.011
# Iter 64/100 - Loss: 1.083   lengthscale: 0.164   noise: 0.011
# Iter 65/100 - Loss: 1.067   lengthscale: 0.165   noise: 0.011
# Iter 66/100 - Loss: 1.052   lengthscale: 0.166   noise: 0.011
# Iter 67/100 - Loss: 1.037   lengthscale: 0.167   noise: 0.011
# Iter 68/100 - Loss: 1.022   lengthscale: 0.168   noise: 0.011
# Iter 69/100 - Loss: 1.008   lengthscale: 0.169   noise: 0.011
# Iter 70/100 - Loss: 0.995   lengthscale: 0.170   noise: 0.011
# Iter 71/100 - Loss: 0.982   lengthscale: 0.171   noise: 0.011
# Iter 72/100 - Loss: 0.969   lengthscale: 0.172   noise: 0.011
# Iter 73/100 - Loss: 0.957   lengthscale: 0.173   noise: 0.011
# Iter 74/100 - Loss: 0.945   lengthscale: 0.174   noise: 0.011
# Iter 75/100 - Loss: 0.933   lengthscale: 0.175   noise: 0.011
# Iter 76/100 - Loss: 0.922   lengthscale: 0.176   noise: 0.011
# Iter 77/100 - Loss: 0.911   lengthscale: 0.177   noise: 0.011
# Iter 78/100 - Loss: 0.900   lengthscale: 0.178   noise: 0.011
# Iter 79/100 - Loss: 0.890   lengthscale: 0.179   noise: 0.011
# Iter 80/100 - Loss: 0.880   lengthscale: 0.180   noise: 0.011
# Iter 81/100 - Loss: 0.870   lengthscale: 0.181   noise: 0.011
# Iter 82/100 - Loss: 0.860   lengthscale: 0.182   noise: 0.011
# Iter 83/100 - Loss: 0.851   lengthscale: 0.183   noise: 0.011
# Iter 84/100 - Loss: 0.842   lengthscale: 0.183   noise: 0.011
# Iter 85/100 - Loss: 0.833   lengthscale: 0.184   noise: 0.011
# Iter 86/100 - Loss: 0.824   lengthscale: 0.185   noise: 0.011
# Iter 87/100 - Loss: 0.816   lengthscale: 0.186   noise: 0.011
# Iter 88/100 - Loss: 0.808   lengthscale: 0.187   noise: 0.011
# Iter 89/100 - Loss: 0.800   lengthscale: 0.188   noise: 0.011
# Iter 90/100 - Loss: 0.792   lengthscale: 0.188   noise: 0.011
# Iter 91/100 - Loss: 0.784   lengthscale: 0.189   noise: 0.011
# Iter 92/100 - Loss: 0.777   lengthscale: 0.190   noise: 0.011
# Iter 93/100 - Loss: 0.769   lengthscale: 0.191   noise: 0.011
# Iter 94/100 - Loss: 0.762   lengthscale: 0.191   noise: 0.011
# Iter 95/100 - Loss: 0.755   lengthscale: 0.192   noise: 0.011
# Iter 96/100 - Loss: 0.748   lengthscale: 0.193   noise: 0.010
# Iter 97/100 - Loss: 0.742   lengthscale: 0.194   noise: 0.010
# Iter 98/100 - Loss: 0.735   lengthscale: 0.194   noise: 0.010
# Iter 99/100 - Loss: 0.729   lengthscale: 0.195   noise: 0.010
# Iter 100/100 - Loss: 0.723   lengthscale: 0.196   noise: 0.010

# %%
with torch.no_grad():
    # Initialize plot
    f, ax = plt.subplots(1, 1, dpi=100)
    
    raw_train_x = np.exp(train_x.numpy() * (x.max() - x.min()))
    raw_test_x  = np.exp(test_x.numpy() * (x.max() - x.min()))
    raw_integer_k = np.exp(log_k.numpy() * (x.max() - x.min()))
    
    lower, upper = observed_pred.confidence_region()
    # plot the fitted Gaussian and training data
    ax.scatter(raw_train_x, np.exp(train_y.numpy()), marker=".", color="black", label="Training data")
    ax.plot(raw_test_x, np.exp(observed_pred.mean.numpy()), 'b', label="Fitted GP")
    ax.fill_between(raw_test_x, np.exp(lower.numpy()), np.exp(upper.numpy()), alpha=0.3)
    
    # plot predicted value with integer k
    ax.scatter(raw_integer_k, np.exp(observed_pred_k.mean.numpy()), marker="^", s=10, color="red", label="Integer k")
    
    ax.set_yscale("log")
    ax.set_xscale("log")
    ax.legend()
    ax.grid(which="both", linestyle=":", alpha=0.3)
    ax.set_title(r"$Re_\lambda=60.7$")
    plt.tight_layout()

# %%
np.exp(observed_pred_k.mean.numpy())
# Out:
# array([0.0039936 , 0.01676238, 0.0179169 , 0.01414952, 0.01111778,
#        0.00910054, 0.0077126 , 0.00669012, 0.00589079, 0.00523937,
#        0.00469429, 0.00423069, 0.00383227, 0.00348739, 0.00318709,
#        0.00292426, 0.00269304, 0.00248857, 0.00230681, 0.00214435,
#        0.00199836, 0.00186644, 0.00174659, 0.00163715, 0.00153672,
#        0.00144411, 0.00135834, 0.00127859, 0.00120417, 0.0011345 ,
#        0.00106909, 0.00100754, 0.00094949, 0.00089467, 0.00084281,
#        0.00079372, 0.00074721, 0.00070313, 0.00066135, 0.00062173,
#        0.00058419, 0.00054861, 0.00051491, 0.00048302, 0.00045285,
#        0.00042433, 0.00039739, 0.00037197, 0.000348  , 0.00032541,
#        0.00030414, 0.00028415, 0.00026535, 0.0002477 , 0.00023115])
